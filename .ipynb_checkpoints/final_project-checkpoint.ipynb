# %%
import pandas as pd

# %%
df = pd.read_csv('data/final/12-US-House-poll-responses-clean.tsv', sep='\t', lineterminator='\n')

# %%
df.head()
# Out:
#    Democrat  Republican  Undecided  Other  Not Voting  \
# 0      44.0        44.0        9.0    2.0         1.0
# 1      48.0        49.0        1.0    NaN         NaN
# 2      47.0        46.0        7.0    NaN         NaN
# 3      46.0        46.0        7.0    1.0         1.0
# 4      46.0        46.0        5.0    3.0         NaN
#
#                    poll_slug           survey_house  start_date    end_date  \
# 0     yougov-economist-16733       YouGov/Economist  2012-11-03  2012-11-05
# 1                  cnn-16606                    CNN  2012-11-02  2012-11-04
# 2  dailykos-seiu-ppp-d-16640  DailyKos/SEIU/PPP (D)  2012-11-01  2012-11-04
# 3    democracy-corps-d-16617    Democracy Corps (D)  2012-11-01  2012-11-04
# 4            rasmussen-16649              Rasmussen  2012-10-29  2012-11-04
#
#    question_text sample_subpopulation  observations  margin_of_error  \
# 0            NaN        Likely Voters         743.0              NaN
# ...

# %%
df_election_2012 = pd.read_excel('data/final/federalelections2012.xls', sheet_name=12)

# %%
df_election_2012.head()
# Out:
#      1 STATE ABBREVIATION        STATE    D    FEC ID#  (I)  \
# 0  2.0                NaN          NaN  NaN        NaN  NaN
# 1  3.0                 CT  Connecticut  NaN        NaN  NaN
# 2  4.0                 CT  Connecticut   01  H8CT01046  (I)
# 3  6.0                 CT  Connecticut   01  H2CT01163  NaN
# 4  7.0                 CT  Connecticut   01  H2CT01155  NaN
#
#   CANDIDATE NAME (First) CANDIDATE NAME (Last)        CANDIDATE NAME  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN            DISTRICT 1
# 2                John B.                Larson       Larson, John B.
# 3             John Henry                Decker    Decker, John Henry
# 4             Michael W.              McDonald  McDonald, Michael W.
#
#   TOTAL VOTES    ...     CONVENTION VOTES 2ND BALLOT CONVENTION % 2ND BALLOT  \
# 0         NaN    ...                             NaN                     NaN
# ...

# %%
raising_2012 = pd.read_csv('data/final/weball12.txt', sep='|', lineterminator='\n')
